# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushan9706/Concepts-and-Technologies-of-AI/blob/main/Sushan_ShresthaWeek_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this exercise, you’ll work with daily time allocation data recorded by a group of students.
# Each student tracked the number of hours spent studying, watching entertainment, and
# sleeping for 15 consecutive days.
# • Dataset: Each record represents one day’s data in the format: (study hours, entertainment hours, sleep hours)
#
# • A sample dataset is provided below.
#
# Daily Student Productivity Data
# Daily time (in hours): [study, entertainment, sleep]
#
# time_data = [ (3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0), (4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5), (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0), (3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0), (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0) ]

# %% [markdown]
# Task 1. Classify Study Time:
# 1. Create empty lists for study time classifications:
# (a) Low: less than 3 hours.
# (b) Moderate: between 3 and 5 hours.
# (c) High: more than 5 hours.
# 2. Iterate over the time_data list and add each study hour to the appropriate category.
# 3. Print the lists to verify the classifications.

# %%
time_data = [ (3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
              (4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
              (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
              (3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
              (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0) ]
#1)
low_study = [ ]   #low: less than 3 hours
moderate_study = [ ]    #moderate: between 3 and 5 hrs
high_study = [ ]    #high: more than 5hrs
#2)
for data in time_data:
  study_hour = data[0]
  if study_hour<3:
    low_study.append(study_hour)
  elif 3 <= study_hour <= 5:
    moderate_study.append(study_hour)
  else:
    high_study.append(study_hour)
#3)
print(f"Low study: {low_study}")
print(f"Moderate study: {moderate_study}")
print(f"High study: {high_study}")
# Out:
# Low study: [2.5, 1.5, 2.0, 2.5]
# Moderate study: [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High study: [5.5, 6.0]

# %% [markdown]
# Task 2. Based on Data – Answer all the Questions:
# 1. How many days had low study time?
# (a) Hint: Count the number of items in the low study list and print the result.
# 2. How many days had moderate study time?
# 3. How many days had high study time?

# %%
#1)
count_lowStudy = len(low_study)
print(f"The number of items in the low study list is: {count_lowStudy}")
#2)
count_moderateStudy = len(moderate_study)
print(f"The number of items in the moderate study list is: {count_moderateStudy}")
#3)
count_highStudy = len(high_study)
print(f"The number of items in the high study list is: {count_highStudy}")
# Out:
# The number of items in the low study list is: 4
# The number of items in the moderate study list is: 9
# The number of items in the high study list is: 2

# %% [markdown]
# Task 3. Convert Study Hours to Minutes:
# Convert each study hour value into minutes and store it in a new list called study_minutes.
#
# Formula: Minutes = Hours × 60
#
# 1. Iterate over the time_data list and apply the formula to the study hours.
# 2. Store the results in the new list.
# 3. Print the converted values.

# %%
study_minutes = []
for data in time_data:
  study_hour = data[0]
  time_minutes = study_hour * 60
  study_minutes.append(time_minutes)
print(f"Studty hours in minutes: {study_minutes}")
# Out:
# Studty hours in minutes: [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %% [markdown]
# Task 4. Analyze Average Time Use:
# Scenario: Each record contains daily hours of study, entertainment, and sleep.
# 1. Create empty lists for study_hours, entertainment_hours, and sleep_hours.
# 2. Iterate over time_data and extract values into each list.
# 3. Calculate and print:
# (a) Average hours spent studying.
# (b) Average hours spent on entertainment.
# (c) Average hours spent sleeping.

# %%
#1)
study_hours = []
entertainment_hours = []
sleep_hours = []
#2)
time_data = [ (3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
              (4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
              (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
              (3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
              (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0) ]
for data in time_data:
  study = data[0]
  entertainment = data[1]
  sleep = data[2]
  study_hours.append(study)
  entertainment_hours.append(entertainment)
  sleep_hours.append(sleep)
#3)
average_study = sum(study_hours)/len(study_hours)
average_entertainment = sum(entertainment_hours)/len(entertainment_hours)
average_sleep = sum(sleep_hours)/len(sleep_hours)
print(f"Average hours spent studying: {average_study}")
print(f"{average_entertainment}")
print(f"{average_sleep}")
# Out:
# Average hours spent studying: 3.7
# 2.5
# 7.166666666666667

# %% [markdown]
# Task 5. Visualization - Study vs Sleep Pattern:
# 1. Import matplotlib.pyplot as plt.
# 2. Plot a scatter plot with:
# • x-axis: Study hours
# • y-axis: Sleep hours
# 3. Add labels, title, and color.

# %%
import matplotlib.pyplot as plt
study_hours = [data[0] for data in time_data]
sleep_hours = [data[2] for data in time_data]
plt.scatter(study_hours, sleep_hours, color='green')
plt.xlabel("Study hours")
plt.ylabel("Sleep hours")
plt.title("Study vs Sleep Pattern")
plt.show()

# %% [markdown]
# 8 Problem based on Popular Algorithm.
#
# 8.1.1 Exercise - Recursion:
# Task 1 - Sum of Nested Lists:
# Scenario: You have a list that contains numbers and other lists of numbers (nested lists).
# You want to find the total sum of all the numbers in this structure.
# Task:
# • Write a recursive function sum_nested_list(nested_list) that:
# 1. Takes a nested list (a list that can contain numbers or other lists of numbers) as
# input.
# 2. Sums all numbers at every depth level of the list, regardless of how deeply nested
# the numbers are.
# • Test the function with a sample nested list, such as
# nested_list = [1, [2, [3, 4], 5], 6, [7, 8]].
# The result should be the total sum of all the numbers.
# Sample Code - Sum of Nested lists.
#
# def sum_nested_list(nested_list):
# """
# Calculate the sum of all numbers in a nested list.
# This function takes a list that may contain integers and other nested lists.
# It recursively traverses the list and sums all the integers, no matter how deeply
# nested they are.
# Args:
# nested_list (list): A list that may contain integers or other lists of integers.
# Returns:
# int: The total sum of all integers in the nested list, including those in sublists
# .
# Example:
# >>> sum_nested_list([1, [2, [3, 4], 5], 6, [7, 8]])
# 36
# >>> sum_nested_list([1, [2, 3], [4, [5]]])
# 15
# """
# total = 0
# for element in nested_list:
# if isinstance(element, list): # Check if the element is a list
# total += sum_nested_list(element) # Recursively sum the nested list
# else:
# total += element # Add the number to the total
# return total

# %%
# Out:
# 36

# %% [markdown]
# Task 2 - Generate All Permutations of a String:
# Scenario: Given a string, generate all possible permutations of its characters. This is useful
# for understanding backtracking and recursive depth-first search.
# Task:
# • Write a recursive function generate_permutations(s) that:
# – Takes a string s as input and returns a list of all unique permutations.
# • Test with strings like ”abc” and ”aab”.
#
# print(generate_permutations("abc"))
# # Should return [’abc’, ’acb’, ’bac’, ’bca’, ’cab’, ’cba’]

# %%
def generate_permutations(s):
  '''
  this function gives all the possible arrangements of letters in a string.
  args:
  s: input string
  return:
  a list of all possible arrangements
  '''
  if len(s) <= 1:
      return [s]
  result = []
  for i in range(len(s)):
    current_char = s[i]
    remaining = s[:i] + s[i+1:]
    smaller_permutations = generate_permutations(remaining)
    for permute in smaller_permutations:
      result.append(current_char + permute)
  return result
print(generate_permutations("abc"))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %% [markdown]
# Task:
# 1. Write a recursive function calculate_directory_size(directory) where:
# • directory is a dictionary where keys represent file names (with values as sizes in
#
# KB) or directory names (with values as another dictionary representing a subdi-
# rectory).
#
# • The function should return the total size of the directory, including all nested
# subdirectories.
#
# 2. Test the function with a sample directory structure.

# %%
def calculate_directory_size(directory):
  '''
    this function calculates the total size of all files in a folder and its subfolders
    args:
    directory: A dictionary representing folders and files
      Files are like "filename": size_number
      Folders are like "foldername": {more files inside}
    returns:
    the total size of all files in KB
  '''
  total_size = 0
  for item_name, item_value in directory.items():
    if isinstance(item_value, int):
      total_size += item_value
    elif isinstance(item_value, dict):
      total_size += calculate_directory_size(item_value)
  return total_size
sample_directory = {
    "file1.txt": 100,
    "file2.txt": 200,
    "subdir1": {
        "file3.txt": 150,
        "file4.txt": 50,
        "subdir2": {
            "file5.txt": 75
        }
    },
    "file6.txt": 300
}

result = calculate_directory_size(sample_directory)
print("Total directory size:", result, "KB")
# Out:
# Total directory size: 875 KB

# %% [markdown]
# 8.2 Dynamic Programming:
#
# Task 1 - Coin Change Problem:
# Scenario: Given a set of coin denominations and a target amount, find the minimum number
# of coins needed to make the amount. If it’s not possible, return - 1.
# Task:
# 1. Write a function min_coins(coins, amount) that:
# • Uses DP to calculate the minimum number of coins needed to make up the
# amount.
# 2. Test with coins = [1, 2, 5] and amount = 11. The result should be 3 (using coins
# [5, 5, 1]).

# %%
def min_coins(coins, amount):
  '''
  this function finds the minimum number of coins needed to make an amount
  args:
  coins: list of available coins
  amount: the target amount to make
  returns:
  minimum number of coins needed
  '''
  dp = [float('inf')] * (amount + 1)
  dp[0] = 0
  for i in range(1, amount + 1):
    for coin in coins:
      if coin <= i:
        dp[i] = min(dp[i], dp[i - coin] + 1)
  return dp[amount] if dp[amount] != float('inf') else -1
coins = [1, 2, 5]
amount = 11
result = min_coins(coins, amount)
print(f"Minimum coins needed: {result}")
# Out:
# Minimum coins needed: 3

# %% [markdown]
# Task 2 - Longest Common Subsequence (LCS):
#
# Scenario: Given two strings, find the length of their longest common subsequence (LCS).
#
# This is useful in text comparison.
#
# Task:
# 1. Write a function longest_common_subsequence(s1, s2) that:
# • Uses DP to find the length of the LCS of two strings s1 and s2.
# 2. Test with strings like "abcde" and "ace"; the LCS length should be 3 ("ace").

# %%
def longest_common_subsequence(s1, s2):
  '''
  this function finds the length of the longes common sequence between two strings.
  args:
  s1: First string (like "abcde")
  s2: Second string (like "ace")
  returns:
  The length of the longest common sequence
  '''
  m, n = len(s1), len(s2)
  dp = [[0] * (n + 1) for _ in range(m + 1)]
  for i in range(1, m + 1):
    for j in range(1, n + 1):
      if s1[i - 1] == s2[j - 1]:
        dp[i][j] = dp[i - 1][j - 1] + 1
      else:
        dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
  return dp[m][n]
s1 = "abcde"
s2 = "ace"
result = longest_common_subsequence(s1, s2)
print(f"Longest Common Subsequence length: {result}")
# Out:
# Longest Common Subsequence length: 3

# %% [markdown]
# Task 3 - 0/1 Knapsack Problem:
#
# Scenario: You have a list of items, each with a weight and a value.
# Given a weight capacity,
# maximize the total value of items you can carry without exceeding the weight capacity.
#
# Task:
# 1. Write a function knapsack(weights, values, capacity) that:
#
# • Uses DP to determine the maximum value that can be achieved within the given
# weight capacity.
#
# 2. Test with weights [1, 3, 4, 5], values [1, 4, 5, 7], and capacity 7. The re-
# sult should be 9.

# %%
def knapsack(weights, values, capacity):
  '''
  This function solves the knapsack problem - choosing items to maximize value without exceeding weight limit.
  args:
  weights: List of item weights (like [1, 3, 4, 5])
  values: List of item values (like [1, 4, 5, 7])
  capacity: Maximum weight the knapsack can hold (like 7)
  returns:
  The maximum total value that can be achieved
  '''
  n = len(weights)
  dp = [[0] * (capacity + 1) for _ in range(n + 1)]
  for i in range(1, n + 1):
    for w in range(1, capacity + 1):
      if weights[i - 1] <= w:
        dp[i][w] = max(dp[i - 1][w],
                   values[i - 1] + dp[i - 1][w - weights[i - 1]])
      else:
        dp[i][w] = dp[i - 1][w]
  return dp[n][capacity]
weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
result = knapsack(weights, values, capacity)
print(f"Maximum value: {result}")
# Out:
# Maximum value: 9
